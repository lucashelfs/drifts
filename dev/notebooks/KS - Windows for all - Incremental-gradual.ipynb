# %% [markdown]
# ### Helper for loading the datasets

# %%
import pandas as pd
from usp_stream_datasets import *

pd.set_option('mode.use_inf_as_na', True)

dataset = "Incremental-gradual (imbal.)"

attr_columns = ['Att1', 'Att2', 'Att3', 'Att4', 'Att5', 'Att6', 'Att7', 'Att8', 'Att9',
                'Att10', 'Att11', 'Att12', 'Att13', 'Att14', 'Att15', 'Att16', 'Att17',
                'Att18', 'Att19', 'Att20', 'Att21', 'Att22', 'Att23', 'Att24', 'Att25',
                'Att26', 'Att27', 'Att28', 'Att29', 'Att30', 'Att31', 'Att32', 'Att33']

main_df = load_insect_dataset(insects_datasets[dataset]["filename"])
classes = main_df['class'].unique().tolist()
minimal_class = main_df["class"].value_counts().min()
window_size = int(minimal_class * 0.25)

# %% [markdown]
# ### Load a specific Dataset

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from scipy import stats


def slice_species_dataframes(main_df, species: str):
    df_species = main_df[main_df["class"] == species]
    df_baseline = df_species.iloc[:window_size,]
    df_stream = df_species.iloc[window_size:,]
    # print(f'Baseline shape {df_baseline.shape}')
    # print(f'Stream shape {df_stream.shape}')
    return df_baseline, df_stream


def test_class_attr(species: str, attr: str):
    df_baseline, df_stream = slice_species_dataframes(main_df, species)
    output_filename = f"results/{species}_ks_{window_size}.csv"
    results = []
    count = window_size
    windows = df_stream[attr].rolling(window=window_size)
    
    for window in windows:
        ks = stats.kstest(df_baseline[attr], window)
        if ks.pvalue < 0.05:
            action = "reject"
        else:
            action = "accept"
        results.append({"attr": attr, "start_index": count - window_size, "end_index": count, "p_value": ks.pvalue})
        count += 1

    df_results = pd.DataFrame(results)
    df_results.to_csv(output_filename, index=False)
    return

# %% [markdown]
# ## Run KS tests for all classes with minimal window and store in respective file

# %%
import time

for species in classes[1:]:
    species_start_time = time.time()   
    for attr in attr_columns:
        attr_start_time = time.time()
        print(f"Testing KS windows on species: {species} - {attr}")
        test_class_attr(species, attr)
        attr_end_time = time.time()
        elapsed_attr_time = attr_end_time - attr_start_time
        print(f'Execution time for {species} - {attr}: {elapsed_attr_time} seconds.')
    
    species_end_time = time.time()
    elapsed_time = species_end_time - species_start_time
    print(f'Total execution time for {species}: {elapsed_time} seconds.')
    print()
# Out:
# Testing KS windows on species: b'ae-aegypti-male' - Att1
# Execution time for b'ae-aegypti-male' - Att1: 17.89472770690918 seconds.
# Testing KS windows on species: b'ae-aegypti-male' - Att2
# Execution time for b'ae-aegypti-male' - Att2: 18.7893545627594 seconds.
# Testing KS windows on species: b'ae-aegypti-male' - Att3
# Execution time for b'ae-aegypti-male' - Att3: 19.14688014984131 seconds.
# Testing KS windows on species: b'ae-aegypti-male' - Att4
# Execution time for b'ae-aegypti-male' - Att4: 19.545159101486206 seconds.
# Testing KS windows on species: b'ae-aegypti-male' - Att5
# Execution time for b'ae-aegypti-male' - Att5: 18.782896518707275 seconds.
# Testing KS windows on species: b'ae-aegypti-male' - Att6
# Execution time for b'ae-aegypti-male' - Att6: 16.58902096748352 seconds.
# Testing KS windows on species: b'ae-aegypti-male' - Att7
# Execution time for b'ae-aegypti-male' - Att7: 16.306382179260254 seconds.
# Testing KS windows on species: b'ae-aegypti-male' - Att8
# Execution time for b'ae-aegypti-male' - Att8: 15.51477575302124 seconds.
# Testing KS windows on species: b'ae-aegypti-male' - Att9
# Execution time for b'ae-aegypti-male' - Att9: 15.491162538528442 seconds.
# Testing KS windows on species: b'ae-aegypti-male' - Att10
# Execution time for b'ae-aegypti-male' - Att10: 15.644660472869873 seconds.
# Testing KS windows on species: b'ae-aegypti-male' - Att11
# Execution time for b'ae-aegypti-male' - Att11: 16.33701753616333 seconds.
# Testing KS windows on species: b'ae-aegypti-male' - Att12
# Execution time for b'ae-aegypti-male' - Att12: 15.862045049667358 seconds.
# Testing KS windows on species: b'ae-aegypti-male' - Att13
# Execution time for b'ae-aegypti-male' - Att13: 16.37693190574646 seconds.
# Testing KS windows on species: b'ae-aegypti-male' - Att14
# Execution time for b'ae-aegypti-male' - Att14: 16.69661283493042 seconds.
# Testing KS windows on species: b'ae-aegypti-male' - Att15
# Execution time for b'ae-aegypti-male' - Att15: 15.811924457550049 seconds.
# Testing KS windows on species: b'ae-aegypti-male' - Att16
# Execution time for b'ae-aegypti-male' - Att16: 16.276469707489014 seconds.
# Testing KS windows on species: b'ae-aegypti-male' - Att17
# Execution time for b'ae-aegypti-male' - Att17: 16.124478101730347 seconds.
# Testing KS windows on species: b'ae-aegypti-male' - Att18
# Execution time for b'ae-aegypti-male' - Att18: 16.237378120422363 seconds.
# Testing KS windows on species: b'ae-aegypti-male' - Att19
# Execution time for b'ae-aegypti-male' - Att19: 15.88692569732666 seconds.
# Testing KS windows on species: b'ae-aegypti-male' - Att20
# Execution time for b'ae-aegypti-male' - Att20: 15.862818717956543 seconds.
# Testing KS windows on species: b'ae-aegypti-male' - Att21
# Execution time for b'ae-aegypti-male' - Att21: 16.304068326950073 seconds.
# Testing KS windows on species: b'ae-aegypti-male' - Att22
# Execution time for b'ae-aegypti-male' - Att22: 16.451813459396362 seconds.
# Testing KS windows on species: b'ae-aegypti-male' - Att23
# Execution time for b'ae-aegypti-male' - Att23: 16.43241024017334 seconds.
# Testing KS windows on species: b'ae-aegypti-male' - Att24
# Execution time for b'ae-aegypti-male' - Att24: 16.973427534103394 seconds.
# Testing KS windows on species: b'ae-aegypti-male' - Att25
# Execution time for b'ae-aegypti-male' - Att25: 16.249311208724976 seconds.
# Testing KS windows on species: b'ae-aegypti-male' - Att26
# Execution time for b'ae-aegypti-male' - Att26: 17.155593872070312 seconds.
# Testing KS windows on species: b'ae-aegypti-male' - Att27
# Execution time for b'ae-aegypti-male' - Att27: 16.771498680114746 seconds.
# Testing KS windows on species: b'ae-aegypti-male' - Att28
# Execution time for b'ae-aegypti-male' - Att28: 16.603055953979492 seconds.
# Testing KS windows on species: b'ae-aegypti-male' - Att29
# Execution time for b'ae-aegypti-male' - Att29: 16.02873468399048 seconds.
# Testing KS windows on species: b'ae-aegypti-male' - Att30
# Execution time for b'ae-aegypti-male' - Att30: 15.667153358459473 seconds.
# Testing KS windows on species: b'ae-aegypti-male' - Att31
# Execution time for b'ae-aegypti-male' - Att31: 16.415834665298462 seconds.
# Testing KS windows on species: b'ae-aegypti-male' - Att32
# Execution time for b'ae-aegypti-male' - Att32: 16.965996026992798 seconds.
# Testing KS windows on species: b'ae-aegypti-male' - Att33
# Execution time for b'ae-aegypti-male' - Att33: 16.470730304718018 seconds.
# Total execution time for b'ae-aegypti-male': 549.6698055267334 seconds.
#
# Testing KS windows on species: b'cx-quinq-female' - Att1
# Execution time for b'cx-quinq-female' - Att1: 12.584288120269775 seconds.
# Testing KS windows on species: b'cx-quinq-female' - Att2
# Execution time for b'cx-quinq-female' - Att2: 12.402915954589844 seconds.
# Testing KS windows on species: b'cx-quinq-female' - Att3
# Execution time for b'cx-quinq-female' - Att3: 12.445592880249023 seconds.
# Testing KS windows on species: b'cx-quinq-female' - Att4
# Execution time for b'cx-quinq-female' - Att4: 12.407641887664795 seconds.
# Testing KS windows on species: b'cx-quinq-female' - Att5
# Execution time for b'cx-quinq-female' - Att5: 12.603225708007812 seconds.
# Testing KS windows on species: b'cx-quinq-female' - Att6
# Execution time for b'cx-quinq-female' - Att6: 12.30514907836914 seconds.
# Testing KS windows on species: b'cx-quinq-female' - Att7
# Execution time for b'cx-quinq-female' - Att7: 12.621535301208496 seconds.
# Testing KS windows on species: b'cx-quinq-female' - Att8
# Execution time for b'cx-quinq-female' - Att8: 12.352737426757812 seconds.
# Testing KS windows on species: b'cx-quinq-female' - Att9
# Execution time for b'cx-quinq-female' - Att9: 12.412590742111206 seconds.
# Testing KS windows on species: b'cx-quinq-female' - Att10
# Execution time for b'cx-quinq-female' - Att10: 12.706945896148682 seconds.
# Testing KS windows on species: b'cx-quinq-female' - Att11
# Execution time for b'cx-quinq-female' - Att11: 12.514879703521729 seconds.
# Testing KS windows on species: b'cx-quinq-female' - Att12
# Execution time for b'cx-quinq-female' - Att12: 12.650111436843872 seconds.
# Testing KS windows on species: b'cx-quinq-female' - Att13
# Execution time for b'cx-quinq-female' - Att13: 12.487967252731323 seconds.
# Testing KS windows on species: b'cx-quinq-female' - Att14
# Execution time for b'cx-quinq-female' - Att14: 13.281126260757446 seconds.
# Testing KS windows on species: b'cx-quinq-female' - Att15
# Execution time for b'cx-quinq-female' - Att15: 13.030281066894531 seconds.
# Testing KS windows on species: b'cx-quinq-female' - Att16
# Execution time for b'cx-quinq-female' - Att16: 12.977164506912231 seconds.
# Testing KS windows on species: b'cx-quinq-female' - Att17
# Execution time for b'cx-quinq-female' - Att17: 12.645086526870728 seconds.
# Testing KS windows on species: b'cx-quinq-female' - Att18
# Execution time for b'cx-quinq-female' - Att18: 12.712026357650757 seconds.
# Testing KS windows on species: b'cx-quinq-female' - Att19
# Execution time for b'cx-quinq-female' - Att19: 13.045586824417114 seconds.
# Testing KS windows on species: b'cx-quinq-female' - Att20
# Execution time for b'cx-quinq-female' - Att20: 12.643903017044067 seconds.
# Testing KS windows on species: b'cx-quinq-female' - Att21
# Execution time for b'cx-quinq-female' - Att21: 12.649224042892456 seconds.
# Testing KS windows on species: b'cx-quinq-female' - Att22
# Execution time for b'cx-quinq-female' - Att22: 12.480708599090576 seconds.
# Testing KS windows on species: b'cx-quinq-female' - Att23
# Execution time for b'cx-quinq-female' - Att23: 12.541447162628174 seconds.
# Testing KS windows on species: b'cx-quinq-female' - Att24
# Execution time for b'cx-quinq-female' - Att24: 12.92168664932251 seconds.
# Testing KS windows on species: b'cx-quinq-female' - Att25
# Execution time for b'cx-quinq-female' - Att25: 12.757611989974976 seconds.
# Testing KS windows on species: b'cx-quinq-female' - Att26
# Execution time for b'cx-quinq-female' - Att26: 13.231549501419067 seconds.
# Testing KS windows on species: b'cx-quinq-female' - Att27
# Execution time for b'cx-quinq-female' - Att27: 12.866868495941162 seconds.
# Testing KS windows on species: b'cx-quinq-female' - Att28
# Execution time for b'cx-quinq-female' - Att28: 12.541352987289429 seconds.
# Testing KS windows on species: b'cx-quinq-female' - Att29
# Execution time for b'cx-quinq-female' - Att29: 12.718232870101929 seconds.
# Testing KS windows on species: b'cx-quinq-female' - Att30
# Execution time for b'cx-quinq-female' - Att30: 12.532624244689941 seconds.
# Testing KS windows on species: b'cx-quinq-female' - Att31
# Execution time for b'cx-quinq-female' - Att31: 12.995367765426636 seconds.
# Testing KS windows on species: b'cx-quinq-female' - Att32
# Execution time for b'cx-quinq-female' - Att32: 13.319156646728516 seconds.
# Testing KS windows on species: b'cx-quinq-female' - Att33
# Execution time for b'cx-quinq-female' - Att33: 12.91309642791748 seconds.
# Total execution time for b'cx-quinq-female': 419.3021013736725 seconds.
#
# Testing KS windows on species: b'cx-quinq-male' - Att1
# Execution time for b'cx-quinq-male' - Att1: 23.06292462348938 seconds.
# Testing KS windows on species: b'cx-quinq-male' - Att2
# Execution time for b'cx-quinq-male' - Att2: 21.798249006271362 seconds.
# Testing KS windows on species: b'cx-quinq-male' - Att3
# Execution time for b'cx-quinq-male' - Att3: 21.518166542053223 seconds.
# Testing KS windows on species: b'cx-quinq-male' - Att4
# Execution time for b'cx-quinq-male' - Att4: 21.73757004737854 seconds.
# Testing KS windows on species: b'cx-quinq-male' - Att5
# Execution time for b'cx-quinq-male' - Att5: 21.4452486038208 seconds.
# Testing KS windows on species: b'cx-quinq-male' - Att6
# Execution time for b'cx-quinq-male' - Att6: 21.360466480255127 seconds.
# Testing KS windows on species: b'cx-quinq-male' - Att7
# Execution time for b'cx-quinq-male' - Att7: 21.71217632293701 seconds.
# Testing KS windows on species: b'cx-quinq-male' - Att8
# Execution time for b'cx-quinq-male' - Att8: 21.375762224197388 seconds.
# Testing KS windows on species: b'cx-quinq-male' - Att9
# Execution time for b'cx-quinq-male' - Att9: 22.1002299785614 seconds.
# Testing KS windows on species: b'cx-quinq-male' - Att10
# Execution time for b'cx-quinq-male' - Att10: 20.92231774330139 seconds.
# Testing KS windows on species: b'cx-quinq-male' - Att11
# Execution time for b'cx-quinq-male' - Att11: 21.07314705848694 seconds.
# Testing KS windows on species: b'cx-quinq-male' - Att12
# Execution time for b'cx-quinq-male' - Att12: 21.02652668952942 seconds.
# Testing KS windows on species: b'cx-quinq-male' - Att13
# Execution time for b'cx-quinq-male' - Att13: 22.266427040100098 seconds.
# Testing KS windows on species: b'cx-quinq-male' - Att14
# Execution time for b'cx-quinq-male' - Att14: 21.37391757965088 seconds.
# Testing KS windows on species: b'cx-quinq-male' - Att15
# Execution time for b'cx-quinq-male' - Att15: 21.207854509353638 seconds.
# Testing KS windows on species: b'cx-quinq-male' - Att16
# Execution time for b'cx-quinq-male' - Att16: 21.638585805892944 seconds.
# Testing KS windows on species: b'cx-quinq-male' - Att17
# Execution time for b'cx-quinq-male' - Att17: 21.23681950569153 seconds.
# Testing KS windows on species: b'cx-quinq-male' - Att18
# Execution time for b'cx-quinq-male' - Att18: 21.713185787200928 seconds.
# Testing KS windows on species: b'cx-quinq-male' - Att19
# Execution time for b'cx-quinq-male' - Att19: 21.168806552886963 seconds.
# Testing KS windows on species: b'cx-quinq-male' - Att20
# Execution time for b'cx-quinq-male' - Att20: 22.23147988319397 seconds.
# Testing KS windows on species: b'cx-quinq-male' - Att21
# Execution time for b'cx-quinq-male' - Att21: 22.46258783340454 seconds.
# Testing KS windows on species: b'cx-quinq-male' - Att22
# Execution time for b'cx-quinq-male' - Att22: 21.764920711517334 seconds.
# Testing KS windows on species: b'cx-quinq-male' - Att23
# Execution time for b'cx-quinq-male' - Att23: 21.250547409057617 seconds.
# Testing KS windows on species: b'cx-quinq-male' - Att24
# Execution time for b'cx-quinq-male' - Att24: 21.328861951828003 seconds.
# Testing KS windows on species: b'cx-quinq-male' - Att25
# Execution time for b'cx-quinq-male' - Att25: 21.595353603363037 seconds.
# Testing KS windows on species: b'cx-quinq-male' -